# %% [markdown]
# **IF_1. СОРТИРАНЕ**
#
# Дадени са 3 цели числа А, В и С. Напишете програма sort, която извежда
# числата в низходящ ред.
#
# **Вход**
#
# На първия ред са числата А, В и С.
#
# **Изход**
#
# Изведете на един ред подредените числа във низходящ ред.
#
# **Ограничения:** $-10^9 ≤ A, B, S ≤ 10^9$.
#
# <br>
#
# **Пример 1**
#
# **Вход**
#
# 5 1 3
#
# **Изход**
#
# 5 3 1
#
# <br>
#
# **Пример 2**
#
# **Вход**
#
# 12 200 12
#
# **Изход**
#
# 200 12 12

# %% [markdown]
# **IF_2. ФИГУРНО ПЪРЗАЛЯНЕ**
#
# В рамките на Зимните олимпийски игри се провежда състезание по фигурно
# пързаляне. Състезателят се оценява като се събират оценките на журито и от
# получената сума се изважда най-високата и най-ниската оценка. Журито се състои от шест човека. Напишете програма **skating**, която пресмята окончателната оценката на състезателя, ако са дадени оценките на журито. Ако журито единодушно дава еднакви оценки, да се пресметне сумата от всички оценки.
#
# **Вход**
#
# На стандартния вход се въвеждат шест цели числа – оценките на всеки член на
# журито. Числата са разделени с по един интервал.
#
# **Изход**
#
# На първия ред на стандартния изход програмата трябва да изведе едно цяло
# число, равно на резултата на състезателя.
#
# **Ограничения**
#
# Най-високата оценка, която може да даде член на журито е 20.
#
# **Пример**
#
# **Вход**
#
# 8 2 3 9 5 6
#
# **Изход**
#
# 22

# %% [markdown]
# **FOR_1. МИНИМАЛНО ЧИСЛО**
#
# Даден е масив А от N цели **различни** числа. Да се изведе най-малкото число в
# масива и на коя позиция се намира.
#
# **Вход**
#
# На първи ред е числото N, на следващия ред са N цели числа.
#
# **Изход**
#
# Изведете на един ред първо намереното минимално число и до него позицията
# му /позицията в масива започва от 1/.
#
# **Ограничения:** $1 ≤ N ≤ 100000, 1 ≤ А_i ≤ 10^9$
#
# **Пример**
#
# **Вход**
#
# 5
#
# 4 6 2 5 9
#
# **Изход**
#
# 2 3

# %% [markdown]
# **FOR_2. Максимална сума**
#
# Дадена е редица от n числа $a_1, a_2, …, a_n$. Да се напише програма maxk, която определя максималната сума на k последователни члена на редицата.
#
# **Вход**
#
# От първия ред на стандартния вход се въвеждат числата n и k. От втория ред се въвеждат числата от редицата.
#
# **Изход**
#
# На стандартния изход да се изведе търсената максимална сума.
#
# **Ограничения:** $1 ≤  k ≤  n ≤ 100000, –9999 ≤  a_i ≤  9999,  i = 1, 2, …, n$
#
# **ПРИМЕР**
#
# **Вход**
#
# 6 2
#
# 4 -2 3 5 1 3
#
# **Изход**
#
# 8

# %% [markdown]
# **FOR_3. РЕДИЦА 1**
#
# Дадена е редица от N числа $А_1, А_2, ..., А_N$. Да се намери най-дългата подредица,в която най-лявото и най-дясното число са равни.
#
# **Вход**
#
# На първия ред е N, на втория ред са числата $A_i$, които са положителни и са до $10^{16}$, $1 <N≤100000$.
#
# **Изход**
#
# Дължината на намерената от вас подредица.
#
# **Забележка:** Гарантира се, че задачата има решение.
#
# **Пример**
#
# **Вход**
#
# 10
#
# 1 3 2 3 5 1 4 2 3 6
#
# **Изход**
#
# 8
#
# **Пояснение на примера:** Подредицата е {3,2,3,5,1,4,2,3}

# %% [markdown]
# **STRING_1. Повече**
#
# Вместо да внимава при предаване на новия урок в час по информатика, Милена пише на приятелите си във facebook. Госпожата забелязала, че всички съобщения, които написала Милена, са с малки латински букви и без интервали между отделните думи.
# Милена получила за домашно да напише програма, която отпечатва буквите, които се срещат в съобщенията повече от един път, подредени по азбучен
# ред. Програмата трябва да извежда и колко пъти се среща всяка буква.
#
# Вие можете да помогнете на Милена като напишете програма more, която решава дадената за домашно задача.
#
#
# **Вход**
#
# От първия ред на стандартния вход се въвежда един низ s, състоящ се от буквите
# ‘a’, ‘b’, ‘c’, ..., ‘z’. Низът не съдържа интервали и винаги има поне една буква, която се среща повече от веднъж.
#
# **Изход**
#
# На стандартния изход програмата трябва да изведе на отделни редове буквите,
# които се срещат в низа s повече от един път, подредени по азбучен ред. След всяка буква да се изведе едно цяло число, равно на броя на срещане на буквата в
# съобщението. Буквата и числото са разделени с един интервал.
#
# **Ограничения**
#
# 1 ≤ брой символи в низа s ≤ 100
#
# **Пример**
#
# **Вход**
#
# wordhello
#
# **Изход**
#
# l 2
#
# o 2

# %% [markdown]
# **STRING_2. ТОМБОЛА**
#
# В училище е организирана коледна томбола. Всеки ученик има номер за участие. Печелят  тези  от    номерата,  в  които има  поне  две еднакви  цифри. Да  се  напише програмаlottery,  която  въвежда  естествено  число nи извежда последнатаповтаряща се цифра в него.
#
# **Вход**
#
# От единствен ред настандартния вход се въвежда естественo число n.
#
# **Изход**
#
# На единствен ред от стандартния изход програмата трябва да изведе последната повтаряща се цифра в числото, ако в записа на няма еднакви цифри,и  „No“,в противен случай
#
# **Ограничения**
#
# 9 < n < 2000000000
#
# **Примери**
#
# |Вход|Изход|
# |---------|-----|
# |234256|2|
# |676678|7|
# |2345|No|

# %% [markdown]
# STRING_3. Релеф
#
# Даден е профил на планински релеф, на който са отбелязани N точки,
# номерирани с числата от 1 до N. Номерацията им започва отляво-надясно, движейки се по релефа. Всяка точка i се намира на височина $H_i$ , Разликата между всеки две точки със съседни номера е 1 m , т.е. $H_i – H_{i–1} = ±1$ за всяко i>1.
# В примера от картинката N=15 и точките са в червено. Височините са означени с
# пунктирани линии и се вижда, че $H_1 =2 m, H_2 =2 m, H_6 = 4 m$. и т.н.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# За всеки два върха i и i+1 е изпълнено $H_i < H_{i+1}$ или $H_i > H_{i+1}$ . За дадения релеф от картинката може да построим редицата: $H_1 <H_2 <H_3 >H_4 <H_5 < ... <H_12 >H_13 <H_14 <H_15$ .
# Знаем, че в релефа има поне една точка с височина 0. Всеки релеф може да се
# зададе с N – 1 знака ‘<’ или ‘>’. За примера по-горе задаването се представя като редицата <<><<>>>><<><<
#
# Напишете програма relef, която намира височините на точките по зададена
# редица от знаци ‘<’ и ’>’.
#
# **Вход**
#
# На първия ред е числото N, на следващия ред е поредица от N – 1 символa $S_i$ , като $S_i$ = '>' означава, че $H_i > H_{i+1}$, а $S_i$ = '<' означава, че $H_i < H_{i+1}$ . , за 1≤ i ≤ N – 1.
#
# **Изход**
#
# Изведете на един ред N числа $H_1 , H_2 , .., H_N$ , където $H_i$ е височината на точката с номер i.
#
# **Ограничения:** 1 ≤ N ≤ 100000.
#
# **Пример**
#
# **Вход**
#
# 15
#
# <<><<>>>><<><<
#
# **Изход**
#
# 1 2 3 2 3 4 3 2 1 0 1 2 1 2 3

# %% [markdown]
# **STRING_4. Парола**
#
# Веднъж  Еркюл  Поаро решил  да смени паролата на своя сейф.  Под  парола той  разбирал  последователност  от  малки латински букви. Измисляйки новата парола, Поаро искал да се убеди, че никой не може да я разгадае.Мосю Бук му подсказал, че безопасна парола е тази, която несъдържа три или повече еднакви символа поред  . В паролата нетрябва да имасимвол, който се среща по-често, отколкото в половината позиции.Напишете  програма   password,  която ще помогне  на Поаро да получи от измислената от него комбинация безопасна парола при минималноколичество операции от вида „заменете i-я  символ  от  низа  с друг  символ“.  Търсенето  на  подходящия символ за заместванезапочва от началото на латинската азбука: ‘a’, ‘b’, ‘c’, ...
#
# **Вход**
#
# На първия ред на стандартния вход се въвежда низ, който се състои от малки латински букви.
#
# **Изход**
#
# На първия ред на стандартния изход програмата трябва да изведе низ – получената безопасна парола.Ако има повече от една възможност за безопасна парола, вашата програма трябва да изведе една от възможните.
#
# **Ограничения**: 2 ≤ брой символи в низа ≤ 5000
#
# **ПРИМЕР**
#
# **Вход**
#
# cooooode
#
# **Изход**
#
# cooaoode

# %% [markdown]
# **2FOR_1. МАТРИЦА 1**
#
# Дадена е матрица A с M реда и N стълба. Да се разменят стълбове с номера P и Q.
#
# **Вход**
#
# На първия ред са числата M, N, P и Q. На следващите М реда има по N цели
# положителни числа $A_{i,j}$.
#
# Изход
#
# Изведете М реда с по N числа – получената от вас матрица след размяна на двата
# стълба от входа.
#
# Ограничения: $1 ≤ M, N ≤ 100, 1 ≤ A_{i,j} ≤ 100, 1 ≤ P,Q ≤ N$.
#
# **Пример**
#
# **Вход**
#
# 3 4 3 1
#
# 2 3 4 1
#
# 1 2 3 3
#
# 4 5 2 1
#
#
# **Изход**
#
# 4 3 2 1
#
# 3 2 1 3
#
# 2 5 4 1

# %% [markdown]
# **2FOR_2. МАТРИЦА 2**
#
# Дадена е матрица A с M реда и N стълба. В матрицата числата са цели,
# положителни и няма две еднакви. Да се разменят местата на минималното и максималното число в матрицата.
#
# **Вход**
#
# На първия ред са числата M и N. На следващите М реда има по N цели
# положителни числа A i,j .
#
# **Изход**
#
# Изведете М реда с по N числа – получената от вас матрица след размяна на
# минималното и максималното число.
#
# **Ограничения:** $1 ≤ M, N ≤ 100, 1 ≤ A_{i,j} ≤ 10^9$ .
#
# **Пример**
#
# **Вход**
#
# 2 3
#
# 2 3 5
#
# 7 8 4
#
# **Изход**
#
# 8 3 5
#
# 7 2 4
